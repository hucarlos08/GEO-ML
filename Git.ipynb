# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # View drive content

# %%
! ls
# Out:
# drive  gdrive  github  sample_data

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Github/Geo-ML
# Out:
# /content/drive/MyDrive/Colab Notebooks/Github/Geo-ML

# %%
! ls
# Out:
# Git.ipynb

# %% [markdown]
# # First time

# %%
# !git clone https://github.com/hucarlos08/GEO-ML.git
# Out:
# Cloning into 'GEO-ML'...
# remote: Enumerating objects: 101, done.
# remote: Counting objects: 100% (101/101), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 101 (delta 44), reused 37 (delta 9), pack-reused 0
# Receiving objects: 100% (101/101), 4.94 MiB | 9.37 MiB/s, done.
# Resolving deltas: 100% (44/44), done.

# %% [markdown]
# # Update
